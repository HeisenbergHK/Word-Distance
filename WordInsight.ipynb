# %% [markdown]
# ### Extracting data from XML

# %%
import xml.etree.ElementTree as ET
import html
import re

xml_file_path = "Data/Posts.xml"

tree = ET.parse(xml_file_path)
root = tree.getroot()

post_data = {}

rows = root.findall("row")
for row in rows:
    post = row.get("Body")
    
    # decodes any HTML entities.
    post = html.unescape(post)

    # re.sub(r'<[^>]+>', '', decoded_body) uses a regular expression to remove anything that looks like
    # an HTML tag. It matches any sequence of characters starting with < and ending with >, and removes it.
    post = re.sub(r'<[^>]+>', '', post)
    
    # Remove escape characters (like \n, \r, etc.) using regular expression
    post = re.sub(r'\\n|\\r|\\t', '', post)
    
    # Remove extra whitespace between sentences or lines
    post = re.sub(r'\s+', ' ', post).strip()

    # Remove punctuation
    post = re.sub(r'[^\w\s]', '', post)
    
    # Lower case all the letters
    post = post.lower()
    
    idx = int(row.get("Id"))
    
    post_data[idx-1] = post

# Example of proccesed data
for i in range(5):
    print(f"{i}: {post_data[i]}\n")
# Out:
# 0: are there universities and labs that are unaffiliated with the tor project that are researching tor and onion routing and contributing back to the tor project be it in code security audits or just publishing papers about how tor could be made more secure if so what labs are out there and what concepts are they researching and where is there funding coming from if that information is available
#
# 1: tor browser bundle ships with noscript which can disable javascript but noscripts functionality is disabled this means that by default in the tor browser bundle all javascript code is allowed to execute  including potentially adversarial code what was the rationale behind this decision
#
# 2: are there any implications if whilst running a nonexit relay i also use the same machine to host a hidden service specifically how will this affect the anonymity of the hidden service in terms of its location being obscured what effect would it have on the anonymity of clients using my relay as a middle node or a guard node are there any other sideeffects i should be aware of
#
# 3: the tor browser bundle ships with javascript enabled because disabling javascript disrupts the user experience and even usability of such a significant portion of the internet that being said you should disable javascript unless you absolutely need it to access a specific site see also the faq entry why is noscript configured to allow javascript by default in the tor browser bundle isnt that unsafe
#
# 4: as i understand it tor nodes and clients bootstrap themselves by contacting over the regular internet some hardcoded addresses to get basic network information what are the effects of this design decision for someone facing a hostile network could a network administrator block this first connection could they impersonate the servers and give false information to the client such that the user thinks they are secure whilst their entire connection is compromised

# %% [markdown]
# ## Tokenization

# %%
import spacy
from collections import Counter

# %%
nlp = spacy.load("en_core_web_sm")
word_count = Counter()

for idx, post in post_data.items():
    doc = nlp(post)

    for token in doc:
        if not token.is_stop and not token.is_space and not token.like_num:
            word_count[token.text] += 1

# %% [markdown]
# ### Saving word_count data

# %%
import pandas as pd

# %%
df = pd.DataFrame(list(word_count.items()), columns=['Word', 'Count'])
df.to_csv('word_count.csv', index=False)

# %%
# Path to your CSV file
file_path = 'word_count.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Convert the DataFrame to a dictionary
word_count = pd.Series(df.Count.values, index=df.Word).to_dict()

word_count = Counter(word_count)

word_count
# Out:
# Counter({'tor': 28774,
#          'nt': 7901,
#          'use': 7444,
#          'browser': 6734,
#          'notice': 5084,
#          'network': 4676,
#          'server': 3911,
#          'connections': 3721,
#          'like': 3664,
#          'service': 3507,
#          'address': 3433,
#          'file': 3423,
#          'node': 3361,
#          'exit': 3321,
#          'ip': 3193,
#          'relay': 3158,
#          'set': 3124,
#          'proxy': 3060,
#          'onion': 2826,
#          'warn': 2761,
#          'm': 2657,
#          'traffic': 2605,
#          'connection': 2551,
#          'directory': 2533,
#          'connect': 2509,
#          'hidden': 2460,
#          'circuit': 2460,
#          'new': 2450,
#          'running': 2446,
#          'want': 2432,
#          'client': 2411,
#          'know': 2411,
#          'need': 2400,
#          'run': 2248,
#          'time': 2247,
#          'port': 2238,
#          'way': 2149,
#          'socks': 2058,
#          'nodes': 1884,
#          'bridge': 1838,
#          'work': 1822,
#          'find': 1730,
#          'tails': 1729,
#          'information': 1713,
#          'problem': 1670,
#          'data': 1661,
#          's': 1660,
#          'user': 1657,
#          'users': 1588,
#          'version': 1584,
#          'access': 1569,
#          'site': 1569,
#          'relays': 1556,
#          'key': 1540,
#          'try': 1538,
#          'torrc': 1537,
#          'possible': 1496,
#          'accept': 1488,
#          'different': 1455,
#          've': 1454,
#          'services': 1433,
#          'website': 1418,
#          'open': 1417,
#          'vpn': 1387,
#          'windows': 1360,
#          'help': 1352,
#          'default': 1351,
#          'question': 1341,
#          'state': 1322,
#          'firefox': 1320,
#          'able': 1306,
#          'internet': 1286,
#          'security': 1247,
#          'read': 1230,
#          'system': 1209,
#          'start': 1208,
#          'example': 1194,
#          'tried': 1171,
#          'listener': 1169,
#          'web': 1149,
#          'install': 1136,
#          'sure': 1135,
#          'error': 1134,
#          'failed': 1120,
#          'bridges': 1115,
#          'settings': 1111,
#          'host': 1101,
#          'log': 1098,
#          'anonymity': 1080,
#          'trying': 1078,
#          'configuration': 1071,
#          'page': 1068,
#          'guard': 1063,
#          'd': 1063,
#          'bootstrapped': 1056,
#          'case': 1031,
#          'sites': 1029,
#          'change': 1025,
#          'option': 1015,
#          'download': 1005,
#          'check': 995,
#          'entry': 994,
#          'disablenetwork': 992,
#          'computer': 991,
#          'following': 985,
#          'existing': 982,
#          'ssl': 980,
#          'line': 975,
#          'list': 974,
#          'dns': 968,
#          'point': 954,
#          'good': 952,
#          'found': 950,
#          'connecting': 944,
#          'public': 934,
#          'works': 934,
#          'installed': 934,
#          'bundle': 931,
#          'control': 930,
#          'circuits': 922,
#          'answer': 911,
#          'working': 896,
#          'add': 894,
#          'code': 891,
#          'people': 890,
#          'linux': 876,
#          'handshake': 874,
#          'files': 869,
#          'think': 866,
#          'shutting': 863,
#          'noncontrol': 839,
#          'allow': 825,
#          'look': 825,
#          'path': 822,
#          'unable': 819,
#          'request': 804,
#          'software': 796,
#          'message': 794,
#          'consensus': 784,
#          'local': 781,
#          'addresses': 780,
#          'private': 780,
#          'websites': 779,
#          'etc': 777,
#          'tcp': 766,
#          'issue': 761,
#          'application': 760,
#          'identity': 755,
#          'uses': 754,
#          'command': 752,
#          'process': 748,
#          'create': 745,
#          'general': 745,
#          'http': 740,
#          'machine': 738,
#          'configured': 736,
#          'yes': 733,
#          'os': 732,
#          'sudo': 723,
#          'encrypted': 720,
#          'bandwidth': 719,
#          'https': 714,
#          'probably': 714,
#          'old': 711,
#          'send': 706,
#          'servers': 700,
#          'router': 698,
#          'update': 697,
#          'configure': 687,
#          'isp': 681,
#          'available': 678,
#          'instead': 678,
#          'source': 665,
#          'number': 664,
#          '_': 662,
#          'build': 661,
#          'tbb': 660,
#          'actually': 660,
#          'opening': 655,
#          'project': 650,
#          'email': 640,
#          'things': 639,
#          'socksport': 638,
#          'thanks': 634,
#          'config': 630,
#          'safe': 628,
#          'based': 627,
#          'ports': 626,
#          'better': 619,
#          'closing': 616,
#          'wo': 615,
#          'means': 614,
#          'google': 608,
#          'info': 603,
#          'eg': 603,
#          'normal': 602,
#          'options': 600,
#          'hop': 600,
#          'link': 598,
#          'search': 596,
#          'firewall': 590,
#          'tors': 590,
#          'setting': 584,
#          'block': 583,
#          'best': 580,
#          'privacy': 580,
#          'setup': 579,
#          'going': 578,
#          'clients': 575,
#          'edit': 574,
#          'specific': 573,
#          'right': 573,
#          'fine': 571,
#          'anonymous': 571,
#          'click': 571,
#          'attack': 566,
#          'understand': 564,
#          'requests': 563,
#          'secure': 562,
#          'support': 562,
#          'wrong': 559,
#          'protocol': 554,
#          'multiple': 549,
#          'location': 547,
#          'long': 544,
#          'note': 542,
#          'says': 540,
#          'country': 538,
#          'folder': 533,
#          'reason': 521,
#          'failure': 521,
#          'got': 517,
#          'connected': 511,
#          'provide': 508,
#          'currently': 506,
#          'handshaking': 506,
#          'whonix': 504,
#          'fingerprint': 502,
#          'died': 502,
#          'having': 497,
#          'maybe': 497,
#          'javascript': 495,
#          'll': 494,
#          'account': 494,
#          'orbot': 493,
#          'idea': 491,
#          'likely': 491,
#          'tell': 491,
#          'downloaded': 486,
#          'looking': 485,
#          'transport': 480,
#          'real': 475,
#          'tls': 474,
#          'end': 471,
#          'ubuntu': 471,
#          'thing': 466,
#          'usb': 461,
#          'descriptor': 459,
#          'browsing': 459,
#          'encryption': 457,
#          'lot': 455,
#          'far': 455,
#          'ipv4': 453,
#          'middle': 449,
#          'domain': 449,
#          'restart': 449,
#          'keys': 443,
#          'single': 443,
#          'bad': 443,
#          'solution': 443,
#          'instance': 441,
#          'browsers': 441,
#          'type': 441,
#          'opened': 441,
#          'known': 440,
#          'obfs4': 440,
#          'apr': 439,
#          'looks': 438,
#          'correct': 433,
#          'directly': 432,
#          'url': 432,
#          'given': 431,
#          'makes': 430,
#          'current': 430,
#          'window': 430,
#          'root': 428,
#          'ie': 425,
#          'mean': 424,
#          'similar': 422,
#          'torbrowser': 422,
#          'applications': 421,
#          'orport': 420,
#          'sep': 419,
#          'logs': 411,
#          'ipv6': 407,
#          'script': 407,
#          'content': 406,
#          'authorities': 405,
#          'debian': 405,
#          'x': 404,
#          'getting': 401,
#          'device': 401,
#          'home': 401,
#          'simply': 400,
#          'prevent': 397,
#          'sent': 396,
#          'blocked': 395,
#          'lines': 394,
#          'nov': 393,
#          'attacks': 392,
#          'certain': 392,
#          'choose': 392,
#          'ssh': 391,
#          'times': 391,
#          'package': 390,
#          'stuck': 390,
#          'iptables': 386,
#          'starting': 386,
#          'bit': 385,
#          'changes': 383,
#          'gpg': 383,
#          'kind': 380,
#          'knows': 379,
#          'questions': 378,
#          'finishing': 375,
#          'ask': 374,
#          'making': 373,
#          'simple': 371,
#          'inside': 370,
#          'output': 370,
#          'rendezvous': 368,
#          'bug': 367,
#          'pluggable': 366,
#          'shows': 366,
#          'details': 364,
#          'fix': 363,
#          'program': 363,
#          'attacker': 362,
#          'regular': 360,
#          'called': 360,
#          'true': 359,
#          'descriptors': 358,
#          'app': 358,
#          'enable': 357,
#          'main': 357,
#          'mac': 355,
#          'vm': 355,
#          'session': 355,
#          'socks5': 354,
#          'load': 352,
#          'count': 352,
#          'copy': 351,
#          'latest': 350,
#          'exitpolicy': 350,
#          'visit': 349,
#          'needs': 348,
#          'asking': 348,
#          'password': 347,
#          'avoid': 347,
#          'virtual': 345,
#          'guards': 345,
#          'disable': 343,
#          'order': 342,
#          'exitnodes': 342,
#          'bootstrapping': 340,
#          'post': 340,
#          'reading': 340,
#          'speed': 340,
#          'test': 339,
#          'ok': 339,
#          'feb': 339,
#          'said': 338,
#          'provider': 337,
#          'created': 334,
#          'successfully': 334,
#          'recommendation': 333,
#          'changed': 332,
#          'cookies': 332,
#          'started': 332,
#          'thank': 332,
#          'route': 331,
#          'adversary': 331,
#          'usually': 330,
#          'discarding': 330,
#          'debug': 330,
#          'issues': 329,
#          'operating': 329,
#          'random': 329,
#          'minutes': 329,
#          'verify': 328,
#          'learn': 327,
#          'warning': 324,
#          'fact': 323,
#          'android': 322,
#          'versions': 320,
#          'exactly': 320,
#          'clearnet': 320,
#          'routing': 319,
#          'policy': 319,
#          'torsocks': 319,
#          'allows': 318,
#          'wifi': 318,
#          'hostname': 316,
#          'longer': 314,
#          'status': 314,
#          'functionality': 313,
#          'bytes': 313,
#          'problems': 312,
#          'mode': 312,
#          'place': 312,
#          'stop': 311,
#          'day': 311,
#          'pm600': 311,
#          'added': 310,
#          'free': 309,
#          'loading': 309,
#          'destination': 308,
#          'openssl': 307,
#          'malicious': 305,
#          'points': 304,
#          'outside': 304,
#          'hiddenserviceport': 303,
#          'level': 300,
#          'let': 297,
#          'easy': 297,
#          'ips': 297,
#          'days': 297,
#          'size': 297,
#          'seconds': 297,
#          'step': 296,
#          'protect': 295,
#          'button': 295,
#          'method': 295,
#          'vidalia': 293,
#          'updated': 291,
#          'flash': 291,
#          'automatically': 291,
#          'enabled': 290,
#          'import': 288,
#          'binary': 288,
#          'adding': 288,
#          'facebook': 286,
#          'blocking': 286,
#          'correctly': 285,
#          'authority': 284,
#          'online': 283,
#          'recommend': 282,
#          'localhost': 281,
#          'write': 279,
#          'properly': 279,
#          'select': 278,
#          'certificate': 278,
#          'etctortorrc': 278,
#          'separate': 277,
#          'received': 277,
#          'noscript': 276,
#          'lets': 275,
#          'login': 275,
#          'disabled': 274,
#          'usage': 273,
#          'packet': 273,
#          'goes': 273,
#          'signature': 272,
#          'result': 272,
#          'arm': 271,
#          'ones': 271,
#          'course': 270,
#          'additional': 268,
#          'packets': 267,
#          'instructions': 267,
#          'bind': 267,
#          'later': 266,
#          'hard': 265,
#          'recently': 265,
#          'manually': 265,
#          'links': 265,
#          'comes': 264,
#          'chrome': 264,
#          'important': 264,
#          'risk': 263,
#          'required': 263,
#          'assume': 262,
#          'appears': 262,
#          'nolongerconfigured': 262,
#          'flag': 260,
#          'happens': 260,
#          'pc': 260,
#          'response': 259,
#          'needed': 258,
#          'drive': 258,
#          'useful': 257,
#          'enter': 257,
#          'believe': 256,
#          'box': 256,
#          'related': 256,
#          'messages': 256,
#          'particular': 255,
#          'p': 255,
#          'remove': 254,
#          'curl': 254,
#          'hours': 253,
#          'listen': 253,
#          'including': 252,
#          'leak': 252,
#          'cases': 252,
#          'ways': 251,
#          'easily': 251,
#          'changing': 251,
#          'hide': 251,
#          'c': 250,
#          'consider': 250,
#          'clear': 249,
#          'image': 249,
#          'come': 248,
#          'matter': 248,
#          'hosting': 248,
#          'completely': 247,
#          'udp': 246,
#          'addons': 246,
#          'provides': 246,
#          'gb': 246,
#          'hello': 246,
#          'feature': 245,
#          'mentioned': 245,
#          'worked': 245,
#          'trust': 244,
#          'contact': 244,
#          'gets': 243,
#          'according': 243,
#          'stream': 243,
#          'hs': 243,
#          'hiddenservicedir': 243,
#          'save': 242,
#          'sending': 242,
#          'include': 242,
#          'person': 242,
#          'little': 242,
#          'exits': 242,
#          'terminal': 242,
#          'compromised': 241,
#          'remote': 241,
#          'phone': 241,
#          'mail': 239,
#          'design': 238,
#          'pretty': 238,
#          'provided': 238,
#          'value': 238,
#          'sends': 237,
#          'recommended': 237,
#          'gateway': 237,
#          'pi': 236,
#          'stable': 236,
#          'official': 236,
#          'results': 236,
#          'seen': 235,
#          'built': 235,
#          'screen': 235,
#          'activity': 234,
#          'basically': 233,
#          'happen': 233,
#          'scripts': 233,
#          'limit': 233,
#          'cell': 232,
#          'documentation': 232,
#          'document': 232,
#          'guess': 231,
#          'live': 231,
#          'close': 231,
#          'forward': 231,
#          'desktop': 230,
#          'introduction': 230,
#          'countries': 229,
#          'runs': 229,
#          'actual': 228,
#          'addon': 228,
#          'reject': 228,
#          'tab': 228,
#          'clock': 227,
#          'specify': 227,
#          'assuming': 226,
#          'connects': 226,
#          'wanted': 226,
#          'controlport': 226,
#          'false': 225,
#          'python': 225,
#          'hope': 225,
#          'installation': 224,
#          'return': 224,
#          'purpose': 223,
#          'downloading': 223,
#          'resolve': 222,
#          'rules': 222,
#          'fast': 221,
#          'ago': 220,
#          'v3': 220,
#          'active': 220,
#          'pm400': 220,
#          'fingerprinting': 219,
#          'depends': 219,
#          'installing': 219,
#          'layer': 219,
#          'bar': 219,
#          'vps': 218,
#          'andor': 218,
#          'systems': 218,
#          'recent': 218,
#          'boot': 217,
#          'reachable': 217,
#          'developers': 217,
#          'custom': 217,
#          'hardware': 216,
#          'steps': 216,
#          'difference': 216,
#          'proxies': 216,
#          'launch': 216,
#          'sslv2v3': 216,
#          'explain': 215,
#          'date': 215,
#          'strictnodes': 215,
#          'requires': 214,
#          'figure': 214,
#          'dirport': 214,
#          'apps': 213,
#          'short': 212,
#          'gives': 212,
#          'cause': 212,
#          'meek': 212,
#          'specifically': 211,
#          'external': 211,
#          'track': 210,
#          'oct': 210,
#          'previous': 209,
#          'protection': 209,
#          'fetches': 208,
#          'leaks': 208,
#          'text': 208,
#          'transparent': 208,
#          'debiantor': 208,
#          'allowed': 207,
#          'great': 207,
#          'checked': 207,
#          'interface': 207,
#          'difficult': 205,
#          'unique': 205,
#          'tool': 204,
#          'common': 204,
#          'small': 204,
#          'authentication': 204,
#          'personal': 204,
#          'section': 204,
#          'j': 204,
#          'wondering': 202,
#          'manual': 202,
#          'receive': 202,
#          'require': 202,
#          'prefer': 202,
#          'updates': 201,
#          'follow': 201,
#          'laptop': 201,
#          'nsa': 201,
#          'menu': 201,
#          'hash': 201,
#          'reasons': 200,
#          'function': 200,
#          'remember': 199,
#          'identify': 199,
#          'object': 199,
#          'video': 198,
#          'openvpn': 198,
#          'cpu': 197,
#          'view': 197,
#          'mind': 197,
#          'static': 197,
#          'valid': 197,
#          'f': 197,
#          'especially': 196,
#          'permissions': 196,
#          'starts': 195,
#          'ensure': 195,
#          'owner': 195,
#          'appear': 195,
#          'research': 194,
#          'guide': 194,
#          'jun': 194,
#          'large': 193,
#          'easier': 193,
#          'listed': 193,
#          'managed': 192,
#          'raspberry': 192,
#          'standard': 192,
#          'answers': 191,
#          'handle': 190,
#          'generated': 190,
#          'establishing': 190,
#          'takes': 189,
#          'years': 189,
#          'share': 189,
#          'internal': 189,
#          'mar': 189,
#          'communication': 188,
#          'necessary': 188,
#          'redirect': 188,
#          'tools': 188,
#          'profile': 188,
#          'flags': 188,
#          'noticed': 188,
#          'checking': 187,
#          'stuff': 187,
#          'closed': 187,
#          'tunnel': 186,
#          'designed': 186,
#          'high': 186,
#          'instances': 186,
#          'aware': 185,
#          'extension': 185,
#          'daemon': 185,
#          'solve': 185,
#          'store': 184,
#          'comment': 184,
#          'normally': 184,
#          'library': 183,
#          'missing': 183,
#          'impossible': 183,
#          'captcha': 183,
#          'nat': 182,
#          'disk': 182,
#          'history': 181,
#          'creating': 181,
#          'geoip': 181,
#          'browse': 180,
#          'break': 180,
#          'packages': 180,
#          'malware': 180,
#          'reach': 180,
#          'extra': 180,
#          'resources': 179,
#          'leave': 179,
#          'fixed': 179,
#          'compromise': 179,
#          'length': 177,
#          'hsdir': 176,
#          'environment': 176,
#          'blog': 176,
#          'described': 176,
#          'pages': 176,
#          'asked': 176,
#          'helps': 175,
#          'original': 175,
#          'memory': 175,
#          'networks': 174,
#          'drop': 174,
#          'big': 174,
#          'complete': 174,
#          'aptget': 174,
#          'routers': 174,
#          'b': 174,
#          'generate': 173,
#          'aboutconfig': 173,
#          'specified': 173,
#          'learned': 173,
#          'transports': 172,
#          'i2p': 172,
#          'perform': 172,
#          'incoming': 172,
#          'socket': 172,
#          'saying': 171,
#          'world': 171,
#          'stem': 171,
#          'generally': 170,
#          'established': 170,
#          'turn': 170,
#          'giving': 170,
#          'exec': 170,
#          'machines': 169,
#          'chain': 169,
#          'networkstatus': 169,
#          'heres': 169,
#          'potentially': 168,
#          'past': 168,
#          'thought': 167,
#          'accessing': 167,
#          'depending': 167,
#          'computers': 167,
#          'month': 167,
#          'logging': 167,
#          'establish': 166,
#          'illegal': 166,
#          'faq': 165,
#          'datadirectory': 165,
#          'government': 165,
#          'fresh': 165,
#          'cookie': 165,
#          'detect': 164,
#          'published': 164,
#          'contains': 164,
#          'suggest': 164,
#          'commands': 164,
#          'controller': 164,
#          'torexe': 164,
#          'target': 163,
#          'future': 163,
#          'ill': 163,
#          'report': 163,
#          'slow': 162,
#          'period': 162,
#          'persistent': 162,
#          'permission': 162,
#          'written': 161,
#          'nginx': 161,
#          'torify': 161,
#          'attempt': 160,
#          'paths': 160,
#          'aug': 160,
#          'tracking': 159,
#          'features': 159,
#          'plugins': 159,
#          'party': 159,
#          'advance': 159,
#          'blocks': 158,
#          'vpns': 158,
#          'entire': 157,
#          'input': 157,
#          'encrypt': 156,
#          'total': 156,
#          'behavior': 156,
#          'nickname': 156,
#          'bookmarks': 155,
#          'upgrade': 155,
#          'finished': 155,
#          'obfs3': 155,
#          'monitor': 154,
#          'considered': 154,
#          'sense': 154,
#          'appreciated': 154,
#          'basic': 153,
#          'threat': 153,
#          'rsa': 153,
#          'coming': 152,
#          'finally': 152,
#          'shared': 152,
#          'dec': 152,
#          'storage': 151,
#          'domains': 151,
#          'located': 151,
#          'loaded': 151,
#          'icon': 151,
#          'wiki': 150,
#          'direct': 150,
#          'testing': 150,
#          'care': 149,
#          'implementation': 149,
#          'forwarding': 149,
#          'supported': 149,
#          'linked': 149,
#          'left': 149,
#          'lan': 149,
#          'fails': 149,
#          'alice': 149,
#          'nyx': 149,
#          'censorship': 148,
#          'article': 148,
#          'cache': 148,
#          'form': 148,
#          'contents': 148,
#          'today': 148,
#          'situation': 147,
#          'errors': 147,
#          'usable': 147,
#          'release': 147,
#          'couple': 147,
#          'tries': 146,
#          'streams': 146,
#          'feel': 146,
#          'modify': 146,
#          'accessible': 146,
#          'anonymously': 146,
#          'stick': 145,
#          'determine': 145,
#          'exist': 145,
#          'warnings': 145,
#          'chance': 145,
#          'understanding': 145,
#          'wish': 145,
#          'ps': 145,
#          'ram': 144,
#          'analysis': 144,
#          'webserver': 144,
#          'went': 144,
#          'building': 144,
#          'manager': 144,
#          'experience': 143,
#          'virtualbox': 143,
#          'watch': 143,
#          'mobile': 143,
#          'libevent': 143,
#          'success': 143,
#          'iso': 143,
#          'programs': 142,
#          'sorry': 142,
#          'cells': 142,
#          'visiting': 142,
#          'happening': 142,
#          'resolution': 141,
#          'java': 141,
#          'listening': 141,
#          'hops': 141,
#          'ticket': 141,
#          't': 141,
#          'methods': 140,
#          'states': 140,
#          'unfortunately': 140,
#          'bittorrent': 140,
#          'names': 140,
#          'delete': 140,
#          'secret': 140,
#          'devices': 140,
#          'proxychains': 140,
#          'limited': 138,
#          'youtube': 138,
#          'timeout': 138,
#          'includes': 137,
#          'task': 137,
#          'r': 137,
#          'tells': 137,
#          'directories': 137,
#          'removed': 137,
#          'delaying': 137,
#          'pm800': 137,
#          'approach': 136,
#          'string': 136,
#          'routed': 136,
#          'obfsproxy': 136,
#          'anymore': 136,
#          'sort': 136,
#          'deanonymize': 136,
#          'advice': 136,
#          'pass': 135,
#          'play': 135,
#          'shown': 135,
#          'u': 135,
#          'videos': 135,
#          'group': 135,
#          'obviously': 134,
#          'hand': 134,
#          'included': 134,
#          'print': 134,
#          'away': 132,
#          'net': 132,
#          'interested': 132,
#          'knowledge': 132,
#          'signal': 132,
#          'workstation': 132,
#          'channel': 131,
#          'fetch': 131,
#          'switch': 131,
#          'html': 131,
#          'force': 131,
#          'chosen': 131,
#          'uptime': 131,
#          'echo': 131,
#          'contain': 130,
#          'o': 130,
#          'downloads': 130,
#          'mb': 129,
#          'china': 129,
#          'possibly': 129,
#          'special': 129,
#          'fully': 129,
#          'extensions': 129,
#          'atlas': 129,
#          'wget': 129,
#          'username': 128,
#          'increase': 128,
#          'looked': 128,
#          'sign': 128,
#          'intended': 128,
#          'plugin': 128,
#          'expected': 128,
#          'match': 127,
#          'explicitly': 127,
#          'talk': 127,
#          'expert': 127,
#          'hosted': 126,
#          'performance': 126,
#          'scenario': 126,
#          'jan': 126,
#          'systemctl': 126,
#          'publish': 125,
#          'talking': 125,
#          'outgoing': 125,
#          'torbutton': 125,
#          'ideas': 125,
#          'exact': 125,
#          'anybody': 124,
#          'man': 124,
#          'seeing': 124,
#          'advanced': 124,
#          'header': 123,
#          'unknown': 123,
#          'entirely': 123,
#          ...})

# %% [markdown]
# ## Top 10 word

# %%
top_10 = word_count.most_common(10)
for word, count in top_10:
    print(f"{word}: {count}")
# Out:
# tor: 28774
# nt: 7901
# use: 7444
# browser: 6734
# notice: 5084
# network: 4676
# server: 3911
# connections: 3721
# like: 3664
# service: 3507

# %% [markdown]
# ## Word Distances

# %% [markdown]
# ### Importing word distance algorithms

# %%
import sys
sys.path.append("16_word_distance_algorithms/")

# %%
import nltk
nltk.download('punkt_tab')
nltk.download("cmudict")

from bagDistance import BagDistance
from damerau import damerau_levenshtein_distance
from dice import dice_coefficient
from editex import editex_distance
from hamming import hamming_distance
from jaccard import jaccard_similarity
from jaro import jaro_distance
from jarowinkler import jaro_winkler_similarity
from lcs import lcs
from lcsubstring import LCSubStr
from levenshte import levenshtein_distance 
from overlapCoefficient import overlap_coefficient
from q_grams import find_common_qgrams
from Smith_Waterman import smith_waterman
from sylabble_allignment import align_syllables
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/hassankalantari/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package cmudict to
# [nltk_data]     /Users/hassankalantari/nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!

# %% [markdown]
# ### Implemting a calculator funtion

# %%
import numpy as np

def most_simular(function):
    distances = {}
    for word, count in top_10:
        
        sim = {}
        c = 0
        for token in word_count.keys():
            if not isinstance(token, str):
                 continue
            sim[token] = function(word, token)
        
        keys = list(sim.keys())
        values = list(sim.values())
        
        max_indexes = np.argsort(values)
        
        for idx in max_indexes[::-1]:
            if keys[idx] != word:
                distances[word] = keys[idx]
                break
                       
    return distances

# %% [markdown]
# ### Bag Distance

# %%
bag_distance = most_simular(BagDistance().get_sim_score)
bag_distance

# %% [markdown]
# ### Jaro Distance

# %%
jaro_distances = most_simular(jaro_distance)
jaro_distances
# Out:
# {'tor': 'xtor',
#  'nt': 'ntt',
#  'use': 'fuse',
#  'browser': 'browsers',
#  'notice': 'noticed',
#  'network': 'networks',
#  'server': 'servers',
#  'connections': 'connections3',
#  'like': 'likes',
#  'service': 'services'}

# %% [markdown]
# ### Jaro Winkler Distance

# %%
jaro_winkler_distances = most_simular(jaro_winkler_similarity)
jaro_winkler_distances
# Out:
# {'tor': 'tore',
#  'nt': 'ntt',
#  'use': 'uses',
#  'browser': 'broswer',
#  'notice': 'noticed',
#  'network': 'netowrk',
#  'server': 'sever',
#  'connections': 'ections',
#  'like': 'liek',
#  'service': 'servicei'}

# %% [markdown]
# ### LCS Distance

# %%
lcs_distances = most_simular(lcs)
lcs_distances
# Out:
# {'tor': 'cusersmestore2',
#  'nt': 'universities',
#  'use': 'universities',
#  'browser': 'browserdatatorgeoip6',
#  'notice': 'torhttpsecurityubuntucomubuntupoolmainmmysql57mysqlservercore57_57230ubuntu018041_amd64deb',
#  'network': 'httptechapplenet201610howtousekronymoustoaccesstornetworkonchromebrowsergooglechromeoschromebooks',
#  'server': 'servicetorrun',
#  'connections': 'connection_edge_process_relay_cell',
#  'like': 'httpssecuritystackexchangecomquestions48502tortrafficcorrelationattacksbyglobaladversaries',
#  'service': 'varlibtorhidden_servicehost'}

# %% [markdown]
# ### LCS Substring Distance

# %%
lcs_subtring_distances = most_simular(LCSubStr)
lcs_subtring_distances
# Out:
# {'tor': 'httpresourcesinfosecinstitutecomfbitorexploit',
#  'nt': 'addressmap_clear_transientvoid',
#  'use': 'cuserstrucdocumentstordatator',
#  'browser': 'httpstractorprojectorgprojectstorwikiorgteamscommunityteamsupportwhichplatformsistorbrowseravailablefor',
#  'notice': '161419000notice',
#  'network': 'prefnetworkhttppipeliningmaxrequests',
#  'server': 'etcopenvpnserverconf',
#  'connections': 'internetconnections',
#  'like': 'cdnlike',
#  'service': 'systemlibraryframeworksdirectoryserviceframeworkversionsadirectoryservice'}

# %% [markdown]
# Hassan Kalantari
